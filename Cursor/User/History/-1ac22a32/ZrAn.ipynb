# %%
class GraphNode:
    def __init__(self, name: str, value: int):
        self.name = name
        self.value = value

# %%
nodes = [GraphNode("A", 3)]
# Out:
# Episode 0 Path:
# A(0, 0) -> A(0, 0)
# Episode 100 Path:
# A(0, 0) -> A(0, 0)
# Episode 200 Path:
# A(0, 0) -> A(0, 1) -> A(1, 1) -> A(1, 0) -> A(1, 0) -> A(2, 0) -> A(2, 0) -> A(2, 1) -> A(2, 0) -> A(2, 0) -> A(3, 0) -> A(2, 0) -> A(3, 0) -> A(2, 0) -> A(2, 0) -> A(1, 0) -> A(0, 0)
# Episode 300 Path:
# A(0, 0) -> A(1, 0) -> A(1, 1) -> A(2, 1) -> A(2, 2) -> A(2, 3) -> A(2, 3) -> A(2, 2) -> A(1, 2) -> A(0, 2) -> A(0, 1) -> A(1, 1) -> A(2, 1) -> A(1, 1) -> A(1, 2) -> A(1, 3) -> A(1, 3) -> A(0, 3) -> A(1, 3) -> A(0, 3) -> A(0, 3) -> A(0, 3) -> A(1, 3) -> A(0, 3) -> A(0, 3) -> A(1, 3) -> A(2, 3) -> A(3, 3)
# Episode 400 Path:
# A(0, 0) -> A(0, 1) -> A(0, 0)
# Episode 500 Path:
# A(0, 0) -> A(0, 0)
# Episode 600 Path:
# A(0, 0) -> A(0, 0)
# Episode 700 Path:
# A(0, 0) -> A(0, 0)
# Episode 800 Path:
# A(0, 0) -> A(0, 0)
# Episode 900 Path:
# A(0, 0) -> A(0, 0)
