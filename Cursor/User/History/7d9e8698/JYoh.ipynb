# %%
from src import WhatsappClient

# %%
client = WhatsappClient(DEBUG=True)
await client.initialize_playwright()
# Out:
# 2024-10-17 20:17:49,307 - INFO - Logger initialized.
# 2024-10-17 20:17:49,308 - INFO - Starting Playwright...
# 2024-10-17 20:17:49,503 - INFO - Launching chromium with persistent context...
# 2024-10-17 20:17:50,184 - INFO - chromium launched successfully.

# %%
await client.login()
# Out:
# 2024-10-17 20:17:51,413 - INFO - User is already logged in. Skipping login step.
# 2024-10-17 20:17:53,076 - INFO - Waiting for WhatsApp chats to load...
# 2024-10-17 20:17:57,763 - INFO - WhatsApp chats loaded.

# %%
await client.extract_chat_details_from_side_pane()
# await client.search_pane_scroll_down()
# Out:
# 2024-10-17 20:17:59,827 - INFO - Chat list div found.
# [{'name': 'Zih',
#   'recent_message': 'mf',
#   'time': 'Zih',
#   'unread_messages': '1',
#   'translate_y': 0.0},
#  {'name': 'SHINE FAMILY',
#   'recent_message': ':\xa0',
#   'time': 'SHINE FAMILY',
#   'unread_messages': '138',
#   'translate_y': 72.0},
#  {'name': 'Karthik Anna',
#   'recent_message': 'Missed voice call',
#   'time': 'Karthik Anna',
#   'unread_messages': '0',
#   'translate_y': 144.0},
#  {'name': 'Prathwik',
#   'recent_message': '# <----------------------------------------------------># \xa0\xa0\xa0\xa0# Need a function like this to obtain new and unread messages \xa0\xa0\xa0\xa0async def get_list_of_messages(self): \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"""get_list_of_messages() \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0gets the list of messages in the page \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0""" \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0messages = await self.page.query_selector_all( \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\'//*[@id="pane-side"]/div[2]/div/div/child::div\' \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0) \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0clean_messages = [] \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0for message in messages: \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0_message = (await message.inner_text()).split("\\n") \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0if len(_message) == 2: \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0clean_messages.append( \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0{ \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"sender": _message[0], \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"time": _message[1], \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"message": "", \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"unread": False, \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"no_of_unread": 0, \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"group": False, \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0} \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0) \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0elif len(_message) == 3: \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0clean_messages.append( \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0{ \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"sender": _message[0], \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"time": _message[1], \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"message": _message[2], \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"unread": False, \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"no_of_unread": 0, \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"group": False, \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0} \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0) \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0elif len(_message) == 4: \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0clean_messages.append( \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0{ \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"sender": _message[0], \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"time": _message[1], \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"message": _message[2], \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"unread": _message[-1].isdigit(), \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0"no_of_unread": ( \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0int(_message[-1]) if _message[-1].isdigit() else 0 \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\ ...
#   'time': 'Prathwik',
#   'unread_messages': '0',
#   'translate_y': 216.0},
#  {'name': 'AIML Community',
#   'recent_message': ':\xa0',
#   'time': 'AIML Community',
#   'unread_messages': '1',
#   'translate_y': 288.0},
#  {'name': 'AIML Official grp 2021-25',
#   'recent_message': ':\xa0',
#   'time': 'AIML Official grp 2021-25',
#   'unread_messages': '0',
#   'translate_y': 360.0},
#  {'name': 'Ananth Nitte',
#   'recent_message': 'Aight',
#   'time': 'Ananth Nitte',
#   'unread_messages': '0',
#   'translate_y': 432.0},
#  {'name': 'GAN 2024',
#   'recent_message': ':\xa0',
#   'time': 'GAN 2024',
#   'unread_messages': '0',
#   'translate_y': 504.0},
#  {'name': 'AIML Community',
#   'recent_message': ':\xa0',
#   'time': 'AIML Community',
#   'unread_messages': '0',
#   'translate_y': 576.0},
#  {'name': 'Pappa',
#   'recent_message': 'Photo',
#   'time': 'Pappa',
#   'unread_messages': '0',
#   'translate_y': 667.0},
#  {'name': 'Asheesh',
#   'recent_message': 'Photo',
#   'time': 'Asheesh',
#   'unread_messages': '0',
#   'translate_y': 739.0},
#  {'name': 'Rakuten Company Project',
#   'recent_message': ':\xa0',
#   'time': 'Rakuten Company Project',
#   'unread_messages': '0',
#   'translate_y': 811.0},
#  {'name': 'Batch 3...',
#   'recent_message': ':\xa0',
#   'time': 'Batch 3...',
#   'unread_messages': '0',
#   'translate_y': 883.0},
#  {'name': 'Krishna Ngger Acharya',
#   'recent_message': 'Yeah take care',
#   'time': 'Krishna Ngger Acharya',
#   'unread_messages': '0',
#   'translate_y': 955.0},
#  {'name': 'AI bois ',
#   'recent_message': ':\xa0',
#   'time': 'AI bois ',
#   'unread_messages': '0',
#   'translate_y': 1027.0},
#  {'name': 'Deon Xavier Nitte',
#   'recent_message': 'https://mangafire.to/manga/mid-autumn-without-you.lr4q6',
#   'time': 'Deon Xavier Nitte',
#   'unread_messages': '0',
#   'translate_y': 1099.0},
#  {'name': 'Abhishek BOB',
#   'recent_message': 'Photo',
#   'time': 'Abhishek BOB',
#   'unread_messages': '0',
#   'translate_y': 1171.0},
#  {'name': 'Slave #69 (Cousin one)',
#   'recent_message': "Don't apply Hyundai",
#   'time': 'Slave #69 (Cousin one)',
#   'unread_messages': '0',
#   'translate_y': 1243.0},
#  {'name': "Disha Ma'am AIML",
#   'recent_message': 'https://x-cortex-docs.vercel.app/',
#   'time': "Disha Ma'am AIML",
#   'unread_messages': '0',
#   'translate_y': 1315.0}]

# %%
await client.fetch_latest_message()
# Out:
# 2024-10-17 20:18:08,690 - INFO - Chat list div found.
# {'name': 'Zih',
#  'recent_message': 'mf',
#  'time': 'Zih',
#  'unread_messages': '1',
#  'translate_y': 0.0}

# %%
await client.on_new_message(lambda x: print(x))
# Out:
# 2024-10-17 20:18:12,409 - INFO - Starting to listen for new messages.
# 2024-10-17 20:18:13,437 - INFO - Chat list div found.
# {'name': 'Zih', 'recent_message': 'mf', 'time': 'Zih', 'unread_messages': '1', 'translate_y': 0.0}
# 2024-10-17 20:18:15,233 - INFO - Chat list div found.
# {'name': 'Zih', 'recent_message': 'mf', 'time': 'Zih', 'unread_messages': '1', 'translate_y': 0.0}
# 2024-10-17 20:18:17,046 - INFO - Chat list div found.
# {'name': 'Zih', 'recent_message': 'mf', 'time': 'Zih', 'unread_messages': '1', 'translate_y': 0.0}
# 2024-10-17 20:18:18,844 - INFO - Chat list div found.
# {'name': 'Zih', 'recent_message': 'mf', 'time': 'Zih', 'unread_messages': '1', 'translate_y': 0.0}
# 2024-10-17 20:18:20,679 - INFO - Chat list div found.
# {'name': 'Zih', 'recent_message': 'mf', 'time': 'Zih', 'unread_messages': '1', 'translate_y': 0.0}
# 2024-10-17 20:18:22,467 - INFO - Chat list div found.
# {'name': 'Zih', 'recent_message': 'mf', 'time': 'Zih', 'unread_messages': '1', 'translate_y': 0.0}
# 2024-10-17 20:18:24,284 - INFO - Chat list div found.
# {'name': 'Zih', 'recent_message': 'mf', 'time': 'Zih', 'unread_messages': '1', 'translate_y': 0.0}
# 2024-10-17 20:18:26,079 - INFO - Chat list div found.
# {'name': 'Zih', 'recent_message': 'mf', 'time': 'Zih', 'unread_messages': '1', 'translate_y': 0.0}
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 await client.on_new_message(lambda x: print(x))
#
# File ~/GitHub/x-whatsapp/src/__init__.py:625, in WhatsappClient.on_new_message(self, callback_function, interval)
#     622     assert new_message is not None
#     623     callback_function(new_message)
# --> 625 await asyncio.sleep(interval)
#
# File ~/.conda/envs/project/lib/python3.12/asyncio/tasks.py:665, in sleep(delay, result)
#     661 h = loop.call_later(delay,
#     662                     futures._set_result_unless_cancelled,
#     663                     future, result)
#     664 try:
# --> 665     return await future
#     666 finally:
#     667     h.cancel()
#
# CancelledError:

# %%
# await client.search_pane_scroll_down()
await client.chat_pane_scroll_up()

# %%
await client.open_chat_panel("Prathwik")

# %%
from tabulate import tabulate

messages = await client.extract_messages()

table_data = [
    [msg["sender"], msg["time"], msg["message"], str(msg["attachment"])]
    for msg in messages
]
headers = ["Sender", "Time Sent", "Message", "Attachment Details"]

print("Number of previous messages: ", len(messages))
print(tabulate(table_data, headers=headers, tablefmt="grid"))

# %%
## LEAVE THIS AS IT IS GOOD FOR TESTING STUFF
import asyncio
from playwright.async_api import async_playwright
import os

BASE_URL = "https://web.whatsapp.com"


async def initialize_playwright(browser_instance, user_data_dir, headless):
    # TODO: Perform browser level optimizations and other stuff
    playwright = await async_playwright().start()

    browser = await playwright[browser_instance].launch_persistent_context(
        user_data_dir, headless=headless
    )

    page_instance = await browser.new_page()

    # await page_instance.set_viewport_size({"width": 1920, "height": 1080})
    return playwright, browser, page_instance


async def login(page, user_data_dir):
    # TODO: QR code & phone number login via script

    await page.goto(BASE_URL)
    await page.bring_to_front()

    print("Waiting for WhatsApp chats to load...")
    await page.wait_for_selector(
        '//*[@id="pane-side"]/div[2]/div/div/child::div', timeout=600000
    )
    print("WhatsApp chats loaded.")

# %%
playwright, browser, page = await initialize_playwright("chromium", "user_data", False)
await login(page, "user_data")

# %%
## ADD TESTING STUFF HERE
