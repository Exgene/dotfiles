# %%
from src import WhatsappClient

# %%
client = WhatsappClient(DEBUG=True)
await client.initialize_playwright()

# %%
await client.login()

# %%
await client.extract_chat_details_from_side_pane()
# await client.search_pane_scroll_down()

# %%
await client.fetch_latest_message()

# %%
await client.on_new_message(lambda x: print(x))

# %%
# await client.search_pane_scroll_down()
await client.chat_pane_scroll_up()

# %%
await client.open_chat_panel("Prathwik")

# %%
from tabulate import tabulate

messages = await client.extract_messages()

table_data = [
    [msg["sender"], msg["time"], msg["message"], str(msg["attachment"])]
    for msg in messages
]
headers = ["Sender", "Time Sent", "Message", "Attachment Details"]

print("Number of previous messages: ", len(messages))
print(tabulate(table_data, headers=headers, tablefmt="grid"))

# %%
## LEAVE THIS AS IT IS GOOD FOR REFACTORING STUFF
import asyncio
from playwright.async_api import async_playwright
import os

BASE_URL = "https://web.whatsapp.com"


async def initialize_playwright(browser_instance, user_data_dir, headless):
    # TODO: Perform browser level optimizations and other stuff
    playwright = await async_playwright().start()

    browser = await playwright[browser_instance].launch_persistent_context(
        user_data_dir, headless=headless
    )

    page_instance = await browser.new_page()

    # await page_instance.set_viewport_size({"width": 1920, "height": 1080})
    return playwright, browser, page_instance


async def login(page, user_data_dir):
    # TODO: QR code & phone number login via script

    await page.goto(BASE_URL)
    await page.bring_to_front()

    print("Waiting for WhatsApp chats to load...")
    await page.wait_for_selector(
        '//*[@id="pane-side"]/div[2]/div/div/child::div', timeout=600000
    )
    print("WhatsApp chats loaded.")

# %%
playwright, browser, page = await initialize_playwright("chromium", "user_data", False)
await login(page, "user_data")
# Out:
# Waiting for WhatsApp chats to load...
# WhatsApp chats loaded.

# %%
## ADD TESTING STUFF HERE


async def trigger_on_notification():
    await page.expose_function(
        "save_notification",
        lambda title, options: notifications.append(
            {"title": title, "options": options}
        ),
    )

    # Keep the script running
    while True:
        await asyncio.sleep(1)
        notifications = []
        await page.evaluate(
            """
        const originalNotification = window.Notification;
        window.Notification = function(title, options) {
            window.save_notification(title, options);
        }
    """
        )
        print(notifications)

# %%
await trigger_on_notification()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 await trigger_on_notification()
#
# Cell In[9], line 17, in trigger_on_notification()
#      15     await asyncio.sleep(5)
#      16     notifications.clear()
# ---> 17     await page.evaluate(
#      18         """
#      19     if ('Notification' in window) {
#      20         const originalNotification = window.Notification;
#      21         const newNotification = function(title, options) {
#      22             console.log(title, options);
#      23             window.save_notification(title, options);
#      24             if (typeof originalNotification === 'function') {
#      25                 return new originalNotification(title, options);
#      26             }
#      27             // If originalNotification is not a constructor, create a mock notification
#      28             return {
#      29                 title: title,
#      30                 options: options,
#      31                 close: function() {}
#      32             };
#      33         };
#      34         newNotification.requestPermission = originalNotification.requestPermission.bind(originalNotification);
#      35         Object.defineProperty(newNotification, 'permission', {
#      36             get: () => originalNotification.permission
#      37         });
#      38         window.Notification = newNotification;
#      39     } else {
#      40         console.log('Notification API is not available in this context');
#      41     }
#      42 """
#      43     )
#      44     if notifications:
#      45         print("Notifications received:", notifications)
#
# File ~/.conda/envs/project/lib/python3.12/site-packages/playwright/async_api/_generated.py:8332, in Page.evaluate(self, expression, arg)
#    8279 async def evaluate(
#    8280     self, expression: str, arg: typing.Optional[typing.Any] = None
#    8281 ) -> typing.Any:
#    8282     """Page.evaluate
#    8283
#    8284     Returns the value of the `expression` invocation.
#    (...)
#    8328     Any
#    8329     """
#    8331     return mapping.from_maybe_impl(
# -> 8332         await self._impl_obj.evaluate(
#    8333             expression=expression, arg=mapping.to_impl(arg)
#    8334         )
#    8335     )
#
# File ~/.conda/envs/project/lib/python3.12/site-packages/playwright/_impl/_page.py:440, in Page.evaluate(self, expression, arg)
#     439 async def evaluate(self, expression: str, arg: Serializable = None) -> Any:
# --> 440     return await self._main_frame.evaluate(expression, arg)
#
# File ~/.conda/envs/project/lib/python3.12/site-packages/playwright/_impl/_frame.py:278, in Frame.evaluate(self, expression, arg)
#     276 async def evaluate(self, expression: str, arg: Serializable = None) -> Any:
#     277     return parse_result(
# --> 278         await self._channel.send(
#     279             "evaluateExpression",
#     280             dict(
#     281                 expression=expression,
#     282                 arg=serialize_argument(arg),
#     283             ),
#     284         )
#     285     )
#
# File ~/.conda/envs/project/lib/python3.12/site-packages/playwright/_impl/_connection.py:59, in Channel.send(self, method, params)
#      58 async def send(self, method: str, params: Dict = None) -> Any:
# ---> 59     return await self._connection.wrap_api_call(
#      60         lambda: self.inner_send(method, params, False)
#      61     )
#
# File ~/.conda/envs/project/lib/python3.12/site-packages/playwright/_impl/_connection.py:514, in Connection.wrap_api_call(self, cb, is_internal)
#     512     return await cb()
#     513 except Exception as error:
# --> 514     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     515 finally:
#     516     self._api_zone.set(None)
#
# Error: Page.evaluate: TypeError: originalNotification is not a constructor
#     at newNotification (eval at evaluate (:234:30), <anonymous>:7:28)
#     at UtilityScript.evaluate (<anonymous>:241:19)
#     at UtilityScript.<anonymous> (<anonymous>:1:44)
