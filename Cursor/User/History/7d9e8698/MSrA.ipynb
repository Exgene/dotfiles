# %%
from src import WhatsappClient

# %%
client = WhatsappClient(DEBUG=True)
await client.initialize_playwright()

# %%
await client.login()

# %%
await client.extract_chat_details_from_side_pane()
# await client.search_pane_scroll_down()

# %%
await client.fetch_latest_message()

# %%
await client.on_new_message(lambda x: print(x))

# %%
# await client.search_pane_scroll_down()
await client.chat_pane_scroll_up()

# %%
await client.open_chat_panel("Prathwik")

# %%
from tabulate import tabulate

messages = await client.extract_messages()

table_data = [
    [msg["sender"], msg["time"], msg["message"], str(msg["attachment"])]
    for msg in messages
]
headers = ["Sender", "Time Sent", "Message", "Attachment Details"]

print("Number of previous messages: ", len(messages))
print(tabulate(table_data, headers=headers, tablefmt="grid"))

# %%
## LEAVE THIS AS IT IS GOOD FOR REFACTORING STUFF
import asyncio
from playwright.async_api import async_playwright
import os

BASE_URL = "https://web.whatsapp.com"


async def initialize_playwright(browser_instance, user_data_dir, headless):
    # TODO: Perform browser level optimizations and other stuff
    playwright = await async_playwright().start()

    browser = await playwright[browser_instance].launch_persistent_context(
        user_data_dir, headless=headless
    )

    page_instance = await browser.new_page()

    # await page_instance.set_viewport_size({"width": 1920, "height": 1080})
    return playwright, browser, page_instance


async def login(page, user_data_dir):
    # TODO: QR code & phone number login via script

    await page.goto(BASE_URL)
    await page.bring_to_front()

    print("Waiting for WhatsApp chats to load...")
    await page.wait_for_selector(
        '//*[@id="pane-side"]/div[2]/div/div/child::div', timeout=600000
    )
    print("WhatsApp chats loaded.")

# %%
playwright, browser, page = await initialize_playwright("chromium", "user_data", False)
await login(page, "user_data")
# Out:
# Waiting for WhatsApp chats to load...
# WhatsApp chats loaded.

# %%
## ADD TESTING STUFF HERE
async def trigger_on_notification():
    await page.expose_function(
        "save_notification",
        lambda title, options: notifications.append(
            {"title": title, "options": options}
        ),
    )
    notifications = []
    # Keep the script running
    while True:
        await asyncio.sleep(1)
        notifications = []
        await page.evaluate(
            """
        const originalNotification = window.Notification;
        window.Notification = function(title, options) {
            window.save_notification(title, options);
            return new originalNotification(title, options);
        }
    """
        )

    print("Listening for notifications...")

# %%
await trigger_on_notification()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 await trigger_on_notification()
#
# Cell In[42], line 12, in trigger_on_notification()
#       8 notifications = []
#      10 if not notification_setup_done:
#      11     # Register the save_notification function only once
# ---> 12     await page.expose_function(
#      13         "save_notification",
#      14         lambda title, options: notifications.append(
#      15             {"title": title, "options": options}
#      16         ),
#      17     )
#      19     # Override the Notification constructor only once
#      20     await page.evaluate(
#      21         """
#      22         if (!window.notificationOverridden) {
#    (...)
#      30         """
#      31     )
#
# File ~/.conda/envs/project/lib/python3.12/site-packages/playwright/async_api/_generated.py:8605, in Page.expose_function(self, name, callback)
#    8548 async def expose_function(self, name: str, callback: typing.Callable) -> None:
#    8549     """Page.expose_function
#    8550
#    8551     The method adds a function called `name` on the `window` object of every frame in the page. When called, the
#    (...)
#    8601         Callback function which will be called in Playwright's context.
#    8602     """
#    8604     return mapping.from_maybe_impl(
# -> 8605         await self._impl_obj.expose_function(
#    8606             name=name, callback=self._wrap_handler(callback)
#    8607         )
#    8608     )
#
# File ~/.conda/envs/project/lib/python3.12/site-packages/playwright/_impl/_page.py:481, in Page.expose_function(self, name, callback)
#     480 async def expose_function(self, name: str, callback: Callable) -> None:
# --> 481     await self.expose_binding(name, lambda source, *args: callback(*args))
#
# File ~/.conda/envs/project/lib/python3.12/site-packages/playwright/_impl/_page.py:487, in Page.expose_binding(self, name, callback, handle)
#     483 async def expose_binding(
#     484     self, name: str, callback: Callable, handle: bool = None
#     485 ) -> None:
#     486     if name in self._bindings:
# --> 487         raise Error(f'Function "{name}" has been already registered')
#     488     if name in self._browser_context._bindings:
#     489         raise Error(
#     490             f'Function "{name}" has been already registered in the browser context'
#     491         )
#
# Error: Function "save_notification" has been already registered
