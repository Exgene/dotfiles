# %%
from newFile import WhatsappClient
import asyncio

# %%
async def periodic_chat_update(client: WhatsappClient, interval: int = 20):
    """
    Periodically fetches and updates chats for specified users.

    :param client: WhatsappClient instance
    :param interval: Time interval in seconds (default: 20)
    """
    while True:
        await client.update_database("Prathwik")
        await asyncio.sleep(interval)

# %%
client = WhatsappClient()
# Out:
# 2024-10-15 21:05:59,642 - INFO - Logger initialized.
# 2024-10-15 21:05:59,643 - INFO - Starting Playwright...

# %%
await client.initialize_playwright()
# Out:
# 2024-10-15 21:06:00,670 - INFO - Launching chromium with persistent context...
# 2024-10-15 21:06:01,992 - INFO - chromium launched successfully.

# %%
await client.login()
# Out:
# 2024-10-15 21:06:02,889 - INFO - User is already logged in. Skipping login step.
# 2024-10-15 21:06:03,610 - INFO - Waiting for WhatsApp chats to load...
# 2024-10-15 21:06:08,732 - INFO - WhatsApp chats loaded.

# %%
await periodic_chat_update(client)
# Out:
# 2024-10-15 21:06:16,463 - INFO - Fetching chat history for Prathwik (last 10 messages).
# 2024-10-15 21:06:16,464 - INFO - Opening chat panel for contact: Prathwik.
# 2024-10-15 21:06:16,488 - INFO - Found search input for contact: Prathwik. Typing contact name.
# 2024-10-15 21:06:17,144 - INFO - Fetching chat history for the last 10 messages.
# 2024-10-15 21:06:18,549 - INFO - Fetched chat history: [{'name': 'Kausthubh J Rao', 'time': '8:10 pm, 15/10/2024', 'message': 'x-cortex-docs.vercel.app'}, {'name': 'Kausthubh J Rao', 'time': '7:39 pm, 15/10/2024', 'message': 'fuck off'}, {'name': 'Prathwik', 'time': '7:39 pm, 15/10/2024', 'message': 'hey'}, {'name': 'Kausthubh J Rao', 'time': '7:38 pm, 15/10/2024', 'message': 'no'}, {'name': 'Prathwik', 'time': '7:29 pm, 15/10/2024', 'message': 'we can divide message retrieval and message sending into two browsers... this will probably make things easier in the short term (later we can consolidate)\n\n\n---\n\n\n\n## SQLite database\n\n\n\n### Scheduled Messages\n\n\n\n-  chatID, provider, Time to send, message\n\n\n\n### Mapper\n\n\n\n(helper to find the correct chatID)\n\n\n\nmaps a number to a chatID\nmap username + provider to chatID\nalso map group name + provider to chatID\n\t- ps. every group has a unique chatID unlike users\n\n\n\n### Chats\n\n\n\nAlso probably add a provider column (eg. whatsapp, telegram, viber etc.)\n\n\n\n| Chat ID | Message ID | Provider                | Sender | Time Sent | Message |\n\n| ------- | ---------- | ----------------------- | ------ | --------- | ------- |\n\n|         |            | Whatsapp / Telegram etc |        |   …'}, {'name': 'Kausthubh J Rao', 'time': '6:50 pm, 15/10/2024', 'message': 'im speaking'}, {'name': 'Kausthubh J Rao', 'time': '6:50 pm, 15/10/2024', 'message': 'it shows in my meet'}, {'name': 'Kausthubh J Rao', 'time': '6:50 pm, 15/10/2024', 'message': 'can you hear me?'}, {'name': 'Kausthubh J Rao', 'time': '6:49 pm, 15/10/2024', 'message': 'i can hear your devious laughs bro'}, {'name': 'Kausthubh J Rao', 'time': '6:49 pm, 15/10/2024', 'message': 'are you there'}]
# 2024-10-15 21:06:18,716 - INFO - Fetching chat history for Kausthubh (last 20 messages).
# 2024-10-15 21:06:18,717 - INFO - Opening chat panel for contact: Kausthubh.
# 2024-10-15 21:06:18,734 - INFO - Found search input for contact: Kausthubh. Typing contact name.
# Added 10 new messages to the database for Prathwik
# 2024-10-15 21:06:19,326 - INFO - Fetching chat history for the last 20 messages.
# 2024-10-15 21:06:20,925 - INFO - Fetched chat history: [{'name': 'Kausthubh J Rao', 'time': '8:10 pm, 15/10/2024', 'message': 'x-cortex-docs.vercel.app'}, {'name': 'Kausthubh J Rao', 'time': '7:39 pm, 15/10/2024', 'message': 'fuck off'}, {'name': 'Prathwik', 'time': '7:39 pm, 15/10/2024', 'message': 'hey'}, {'name': 'Kausthubh J Rao', 'time': '7:38 pm, 15/10/2024', 'message': 'no'}, {'name': 'Prathwik', 'time': '7:29 pm, 15/10/2024', 'message': 'we can divide message retrieval and message sending into two browsers... this will probably make things easier in the short term (later we can consolidate)\n\n\n---\n\n\n\n## SQLite database\n\n\n\n### Scheduled Messages\n\n\n\n-  chatID, provider, Time to send, message\n\n\n\n### Mapper\n\n\n\n(helper to find the correct chatID)\n\n\n\nmaps a number to a chatID\nmap username + provider to chatID\nalso map group name + provider to chatID\n\t- ps. every group has a unique chatID unlike users\n\n\n\n### Chats\n\n\n\nAlso probably add a provider column (eg. whatsapp, telegram, viber etc.)\n\n\n\n| Chat ID | Message ID | Provider                | Sender | Time Sent | Message |\n\n| ------- | ---------- | ----------------------- | ------ | --------- | ------- |\n\n|         |            | Whatsapp / Telegram etc |        |   …'}, {'name': 'Kausthubh J Rao', 'time': '6:50 pm, 15/10/2024', 'message': 'im speaking'}, {'name': 'Kausthubh J Rao', 'time': '6:50 pm, 15/10/2024', 'message': 'it shows in my meet'}, {'name': 'Kausthubh J Rao', 'time': '6:50 pm, 15/10/2024', 'message': 'can you hear me?'}, {'name': 'Kausthubh J Rao', 'time': '6:49 pm, 15/10/2024', 'message': 'i can hear your devious laughs bro'}, {'name': 'Kausthubh J Rao', 'time': '6:49 pm, 15/10/2024', 'message': 'are you there'}, {'name': 'Prathwik', 'time': '4:08 pm, 15/10/2024', 'message': 'hackmd.io'}, {'name': 'Prathwik', 'time': '3:29 pm, 15/10/2024', 'message': 'u are in'}, {'name': 'Kausthubh J Rao', 'time': '3:28 pm, 15/10/2024', 'message': 'lemee in'}, {'name': 'Kausthubh J Rao', 'time': '3:11 pm, 15/10/2024', 'message': 'ok'}, {'name': 'Prathwik', 'time': '3:11 pm, 15/10/2024', 'message': 'join in half hour'}, {'name': 'Prathwik', 'time': '3:11 pm, 15/10/2024', 'message': 'sure'}, {'name': 'Prathwik', 'time': '3:11 pm, 15/10/2024', 'message': 'meet.google.com'}, {'name': 'Kausthubh J Rao', 'time': '3:11 pm, 15/10/2024', 'message': 'after half an hour'}, {'name': 'Prathwik', 'time': '3:11 pm, 15/10/2024', 'message': 'meet?'}, {'name': 'Prathwik', 'time': '3:11 pm, 15/10/2024', 'message': 'hey are you free rn?'}]
# Added 20 new messages to the database for Kausthubh
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 await periodic_chat_update(client)
#
# Cell In[2], line 12, in periodic_chat_update(client, interval)
#      10 while True:
#      11     await client.fetch_and_update_chats(users)
# ---> 12     await asyncio.sleep(interval)
#
# File ~/.conda/envs/project/lib/python3.12/asyncio/tasks.py:665, in sleep(delay, result)
#     661 h = loop.call_later(delay,
#     662                     futures._set_result_unless_cancelled,
#     663                     future, result)
#     664 try:
# --> 665     return await future
#     666 finally:
#     667     h.cancel()
#
# CancelledError:
