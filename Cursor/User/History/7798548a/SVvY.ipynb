# %%
from newFile import WhatsappClient
import asyncio

# %%
async def periodic_chat_update(client: WhatsappClient, interval: int = 20):
    """
    Periodically fetches and updates chats for specified users.

    :param client: WhatsappClient instance
    :param interval: Time interval in seconds (default: 20)
    """
    while True:
        await client.update_database("Karthik")
        await asyncio.sleep(interval)

# %%
client = WhatsappClient()
# Out:
# 2024-10-15 23:03:47,312 - INFO - Logger initialized.
# 2024-10-15 23:03:47,312 - INFO - Starting Playwright...

# %%
await client.initialize_playwright()
# Out:
# 2024-10-15 23:03:48,545 - INFO - Launching chromium with persistent context...
# 2024-10-15 23:03:49,333 - INFO - chromium launched successfully.

# %%
await client.login()
# Out:
# 2024-10-15 23:03:49,989 - INFO - User is already logged in. Skipping login step.
# 2024-10-15 23:03:50,558 - INFO - Waiting for WhatsApp chats to load...
# 2024-10-15 23:03:55,216 - INFO - WhatsApp chats loaded.

# %%
await periodic_chat_update(client)
# Out:
# 2024-10-15 23:04:08,173 - INFO - Fetching chat history for the last 10 messages.
# 2024-10-15 23:04:09,451 - INFO - Fetched chat history: [{'name': 'Kausthubh J Rao', 'time': '10:25 pm, 15/10/2024', 'message': 'this is a test'}, {'name': 'Kausthubh J Rao', 'time': '5:18 pm, 15/10/2024', 'message': 'bondel'}, {'name': 'Karthik Anna', 'time': '7:55 pm, 11/10/2024', 'message': 'Hi'}, {'name': 'Karthik Anna', 'time': '7:55 pm, 11/10/2024', 'message': 'Hi'}, {'name': 'Karthik Anna', 'time': '7:54 pm, 11/10/2024', 'message': 'Hi'}, {'name': 'Kausthubh J Rao', 'time': '8:57 pm, 10/10/2024', 'message': 'where'}, {'name': 'Kausthubh J Rao', 'time': '12:47 pm, 05/10/2024', 'message': 'https://youtu.be/XAJsscjoXMw?si=uBAp8gHFPM6vUURq'}, {'name': 'Kausthubh J Rao', 'time': '4:13 pm, 29/09/2024', 'message': 'fast'}, {'name': 'Kausthubh J Rao', 'time': '4:13 pm, 29/09/2024', 'message': 'which one u want'}, {'name': 'Kausthubh J Rao', 'time': '4:12 pm, 29/09/2024', 'message': ''}]
# Message already exists in the database
# Message already exists in the database
# Message already exists in the database
# Message already exists in the database
# Message already exists in the database
# Message already exists in the database
# Message already exists in the database
# Message already exists in the database
# Message already exists in the database
# Message already exists in the database
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 await periodic_chat_update(client)
#
# Cell In[2], line 10, in periodic_chat_update(client, interval)
#       8 while True:
#       9     await client.update_database("Karthik")
# ---> 10     await asyncio.sleep(interval)
#
# File ~/.conda/envs/project/lib/python3.12/asyncio/tasks.py:665, in sleep(delay, result)
#     661 h = loop.call_later(delay,
#     662                     futures._set_result_unless_cancelled,
#     663                     future, result)
#     664 try:
# --> 665     return await future
#     666 finally:
#     667     h.cancel()
#
# CancelledError:

# %%
import sqlite3
from newFile import get_db_path
from prettytable import PrettyTable


def get_chats_from_db():
    """Gets all chats from the chats table."""
    db_path = get_db_path()
    connection = sqlite3.connect(db_path)
    cursor = connection.cursor()

    cursor.execute("SELECT * FROM chats")
    chats = cursor.fetchall()
    connection.close()
    return chats


# Fetch chats and display them in a table format
chats = get_chats_from_db()

# Create a PrettyTable instance
table = PrettyTable()
table.field_names = [
    "Chat ID",
    "Message ID",
    "Provider",
    "Sender",
    "Time Sent",
    "Message",
]

# Add rows to the table
for chat in chats:
    table.add_row(chat)

# Print the table
print(table)
# Out:
# +---------+----------------------------------+----------+-----------------+----------------------+--------------------------------------------------+
# | Chat ID |            Message ID            | Provider |      Sender     |      Time Sent       |                     Message                      |
# +---------+----------------------------------+----------+-----------------+----------------------+--------------------------------------------------+
# |    1    |                1                 |   test   |       test      | 2023-10-01 12:00:00  |                       test                       |
# | Karthik | fe63240c6c02c92dc2397a5ebcbc2ca0 | whatsapp | Kausthubh J Rao | 10:25 pm, 15/10/2024 |                  this is a test                  |
# | Karthik | 245712cb8e900f22b717e01660bc9c5c | whatsapp | Kausthubh J Rao | 5:18 pm, 15/10/2024  |                      bondel                      |
# | Karthik | ef4fb98d69200f805cd58e5db871bc3a | whatsapp |   Karthik Anna  | 7:55 pm, 11/10/2024  |                        Hi                        |
# | Karthik | 24b7dc58a100fbe0f4f96c892a104214 | whatsapp |   Karthik Anna  | 7:54 pm, 11/10/2024  |                        Hi                        |
# | Karthik | a4e2b99839792b6050f78157de12f166 | whatsapp | Kausthubh J Rao | 8:57 pm, 10/10/2024  |                      where                       |
# | Karthik | e38ee13ae8d584465cbdd01128f03b3e | whatsapp | Kausthubh J Rao | 12:47 pm, 05/10/2024 | https://youtu.be/XAJsscjoXMw?si=uBAp8gHFPM6vUURq |
# | Karthik | df3da427f506cb8b921361e31f8683dc | whatsapp | Kausthubh J Rao | 4:13 pm, 29/09/2024  |                       fast                       |
# | Karthik | 7daaed2491096e1c13a97f821776d0a4 | whatsapp | Kausthubh J Rao | 4:13 pm, 29/09/2024  |                 which one u want                 |
# | Karthik | 889c636e8036573505bb6fe679631beb | whatsapp | Kausthubh J Rao | 4:12 pm, 29/09/2024  |                                                  |
# +---------+----------------------------------+----------+-----------------+----------------------+--------------------------------------------------+
